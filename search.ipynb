# %%
from askgit.services.ingestion import IngestionService

service = IngestionService()
# Out:
# 2025-10-24 12:54:24.551 | INFO     | askgit.services.embeddings:__init__:26 - Initialized EmbeddingService with model=bedrock/eu.cohere.embed-v4:0, batch_size=32
# 2025-10-24 12:54:24.552 | INFO     | askgit.services.ingestion:__init__:36 - Initialized IngestionService

# %%
await service.search_similar("Hi")
# Out:
# 2025-10-24 12:54:34.713 | DEBUG    | askgit.services.embeddings:generate_embeddings_batch:70 - Successfully generated 1 embeddings in batch
# 2025-10-24 12:54:34.772 | INFO     | askgit.services.ingestion:search_similar:298 - Found 2 similar documents for query
# ...
